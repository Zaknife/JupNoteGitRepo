# %%
import matplotlib as mpl
mpl.use("nbagg")
import matplotlib.pyplot as plt
from ipywidgets import *
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib notebook 
# init_notebook_mode()
from IPython.display import HTML
V=4e-1*1.041e-1*0.74e-1
V100=1.038*1e-1*3.9405*1e-1*0.76e-1
m=0.0239
m2=0.0255
m3=0.00585
from IPython.display import Image

HTML('''
<style>

div.cell { /* Tunes the space between cells */
margin-top:1em;
margin-bottom:1em;
}

div.text_cell_render h1 { /* Main titles bigger, centered */
font-size: 1.5em;
line-height:1.5em;
text-align:left;
}

div.text_cell_render h2 { /*  Parts names nearer from text */
margin-bottom: -0.4em;
}


div.text_cell_render { /* Customize text cells */
font-family: 'Helvetica';
font-size:1.2em;
line-height:2em;
padding-left:3em;
padding-right:3em;
}
</style>

<script>
code_show=true; 
function code_toggle() {
if (code_show){
$('div.input').hide();
} else {
$('div.input').show();
}
code_show = !code_show
} 
$( document ).ready(code_toggle);

</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <style>
#
# div.cell { /* Tunes the space between cells */
# margin-top:1em;
# margin-bottom:1em;
# }
#
# div.text_cell_render h1 { /* Main titles bigger, centered */
# font-size: 1.5em;
# line-height:1.5em;
# text-align:left;
# }
#
# div.text_cell_render h2 { /*  Parts names nearer from text */
# margin-bottom: -0.4em;
# }
#
#
# div.text_cell_render { /* Customize text cells */
# font-family: 'Helvetica';
# font-size:1.2em;
# line-height:2em;
# padding-left:3em;
# padding-right:3em;
# }
# </style>
#
# <script>
# code_show=true;
# function code_toggle() {
# if (code_show){
# $('div.input').hide();
# } else {
# $('div.input').show();
# }
# code_show = !code_show
# }
# $( document ).ready(code_toggle);
#
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
#################################
#Beauitiful plot maker in Python#
#################################
#

# These are the "Tableau 20" colors as RGB.    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)      
## TeX preamble
# preamble = [
#     r'\usepackage{fontspec}',
#     r'\setmainfont{Minion Pro}',
#     r'\usepackage[textlf,mathlf,minionint]{MinionPro}'
# ]

params = {
    'font.family': 'sans-serif',
    'font.sans-serif':['Calibri'],
    'text.usetex': False,
    'text.latex.unicode': False,
    'pgf.rcfonts': False,
    'pgf.texsystem': 'xelatex',
}

mpl.rcParams.update(params)

# %%
from IPython.display import HTML
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.models import * 
from bokeh.plotting import figure
from bokeh.charts.utils import cycle_colors
from bokeh.palettes import *
from bokeh.palettes import viridis as palette
import itertools
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1ecbec97-9dbb-4d6b-bf23-93f39a0baff1">Loading BokehJS ...</span>
#     </div>

# %%
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

# %%
dir='../StudiaDoktoranckie/2017/Tensometry/'
TSweepLowTempC1=pd.read_csv(dir+'Tensometr5May17_T4-2K_Cooling#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempC2=pd.read_csv(dir+'Tensometr5May17_T4-2K_Cooling#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempC3=pd.read_csv(dir+'Tensometr5May17_T4-2K_Cooling#3.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempH1=pd.read_csv(dir+'Tensometr5May17_T4-2K_Heating#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempH2=pd.read_csv(dir+'Tensometr5May17_T4-2K_Heating#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempC1=pd.read_csv(dir+'Tensometr5May17_T10-17K_Cooling#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempC2=pd.read_csv(dir+'Tensometr5May17_T10-17K_Cooling#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempH1=pd.read_csv(dir+'Tensometr5May17_T10-17K_Heating#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempH2=pd.read_csv(dir+'Tensometr5May17_T10-17K_Heating#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempH3=pd.read_csv(dir+'Tensometr5May17_T10-17K_Heating#3.csv',sep=',',header=0,error_bad_lines=False)
HSweep8K=pd.read_csv(dir+'Tensometr6May17_H_8K#2.csv',sep=',',header=0,error_bad_lines=False)
HSweep6K=pd.read_csv(dir+'Tensometr6May17_H_6K.csv',sep=',',header=0,error_bad_lines=False)
HSweep5K=pd.read_csv(dir+'Tensometr6May17_H_5K.csv',sep=',',header=0,error_bad_lines=False)
HSweep12K=pd.read_csv(dir+'Tensometr6May17_H_12K.csv',sep=',',header=0,error_bad_lines=False)
RawTempSweep=pd.read_csv(dir+'Tensometr4May17TwoSamples.csv',sep=',',header=0,error_bad_lines=False)

# %% [markdown]
# # 4 - 5 May Overnight absolute measurement of a tensometers alone.

# %% [markdown]
# The tensometers where fed with the 100 $\mu$A RMS current. Temperature was swept in the rate 2 K/min. The measurement was carried out in the 7 T Squid which was previously de-gaussed with "5 T fast" procedure. System's cryogenic performance was malfunctioning during the measurement.
#
# We have veryfied, that resistance characteristic ilustrated below can be attributed to strain gage. We have not seen any signature of sample behavior in this measurement.

# %%
p = figure(title="Absolute strain measurement (10% vs 3 %) 4 May 17", x_axis_label='Temperature (K)', y_axis_label='Tensometer Resistance')
p.x_range=Range1d(2,299)
# p.y_range=Range1d(1.003,1.005)
p.circle(RawTempSweep.ix[:,7],(RawTempSweep.ix[:,1])/1e-4,size=1,color=tableau20[0],legend='T= 8 K')
p.circle(RawTempSweep.ix[:,7],(RawTempSweep.ix[:,2]+0.03568)/1e-4,size=1,color=tableau20[2],legend='T= 6 K')
# p.circle(HSweep5K.ix[:,8],(HSweep5K.ix[:,1]),size=1,color=tableau20[4],legend='T= 5 K')
# p.circle(HSweep12K.ix[:,8],(HSweep12K.ix[:,1]),size=1,color=tableau20[6],legend='T= 12 K')



# p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
# p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
# p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')


p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

p.title.text_font_size='16pt'
p.title.text_font = "helvetica"

vline = Span(location=2.8, dimension='height', line_color='black', line_width=1)
vline = Span(location=14.2, dimension='height', line_color='red', line_width=1)

p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="da4fb44e-f1a3-4e49-9362-7b447222721e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("da4fb44e-f1a3-4e49-9362-7b447222721e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("73b7eabd-e90c-41c9-8bbb-08d2beff2693", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("da4fb44e-f1a3-4e49-9362-7b447222721e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'da4fb44e-f1a3-4e49-9362-7b447222721e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4959965e-2e89-457e-aab6-907a65f4679a":{"roots":{"references":[{"attributes":{"data_source":{"id":"a6f8768f-497d-4473-81fb-b0eb42935e7f","type":"ColumnDataSource"},"glyph":{"id":"6b1437ee-e3d8-422e-8cf3-d6ed8bf55b60","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"b5758f38-e801-4b7e-b882-6b2d6cd084af","type":"Circle"},"selection_glyph":null},"id":"ab2d391e-4a31-4185-804b-c3ba7180f1ef","type":"GlyphRenderer"},{"attributes":{},"id":"c669aa76-7426-4f2a-a68b-440343628475","type":"BasicTicker"},{"attributes":{"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"},"ticker":{"id":"c669aa76-7426-4f2a-a68b-440343628475","type":"BasicTicker"}},"id":"46b1ea01-7bd0-4c68-9f19-693a78f8b423","type":"Grid"},{"attributes":{"axis_label":"Tensometer Resistance","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"0a23ebed-ca53-4020-81bd-a12ba17da298","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"},"ticker":{"id":"f0b79a55-cfd4-49f1-915f-862480358828","type":"BasicTicker"}},"id":"35e55d67-ec96-401c-ade2-671090c573bf","type":"LinearAxis"},{"attributes":{},"id":"f0b79a55-cfd4-49f1-915f-862480358828","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"},"ticker":{"id":"f0b79a55-cfd4-49f1-915f-862480358828","type":"BasicTicker"}},"id":"4606ba75-e2cb-48ca-970e-488c3df2f866","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b5736b45-eb0f-412b-bd70-2c8bae4f0d66","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"rgb(31, 119, 180)"},"line_color":{"value":"rgb(31, 119, 180)"},"size":{"units":"screen","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"6b1437ee-e3d8-422e-8cf3-d6ed8bf55b60","type":"Circle"},{"attributes":{"label":{"value":"T= 8 K"},"renderers":[{"id":"ab2d391e-4a31-4185-804b-c3ba7180f1ef","type":"GlyphRenderer"}]},"id":"41012ee5-f473-45b1-a481-3c37b9a7e9fd","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[17784]},"y":{"__ndarray__":"...","dtype":"float64","shape":[17784]}}},"id":"a6f8768f-497d-4473-81fb-b0eb42935e7f","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"}},"id":"fe32d023-2651-478e-8639-ec5ef3485611","type":"PanTool"},{"attributes":{"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"}},"id":"feec6510-b9dd-4cbd-9ad3-b7603869a79d","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"b5736b45-eb0f-412b-bd70-2c8bae4f0d66","type":"BoxAnnotation"},"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"}},"id":"b862c66d-c7b8-4847-9698-d5e13089c0c3","type":"BoxZoomTool"},{"attributes":{},"id":"0a23ebed-ca53-4020-81bd-a12ba17da298","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"}},"id":"96284a16-fbff-445a-9259-6d0c2a69f789","type":"SaveTool"},{"attributes":{"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"}},"id":"c45f8fcf-1e44-4eaf-b2b0-b4fe784bd2e8","type":"ResetTool"},{"attributes":{"plot":{"id":"16310393-6cc7-4f78-950d-b1ebf15110a5","subtype":"Figure","type":"Plot"}},"id":"92b25f5f-401f-43f8-a63c-213b0f2c5140","type":"HelpTool"},{"attributes":{},"id":"de9d20a0-72cb-4c37-bd07-070ab237a5eb","type":"BasicTickFormatter"},{"attributes":{"dimension":"height","line_color":{"value":"red"},"location":14.2,"plot":null},"id":"7b818 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %% [markdown]
# # Differential measurements 5 and 6 May 17

# %% [markdown]
# As it is shown on the picture above, strain ages are exhibiting steep increase of resistance in the low temperatures. Due to resistance rapid increase, a possibility of detection of the phase transition is low-temp regime is questionable. Low temperature differential measurements presented below are indicating siginificant slope between 4-2 K.

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (mV)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.circle(TSweepLowTempH1.ix[:,7],(TSweepLowTempH1.ix[:,1]),color=tableau20[0],legend='Heating #1')
# p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
# p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=2.8, dimension='height', line_color='black', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f9aac54c-2e7f-4e87-9ba7-385303bc3068"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f9aac54c-2e7f-4e87-9ba7-385303bc3068").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("d25b0a0e-6cbb-495d-bb26-62a6cc925dd9", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f9aac54c-2e7f-4e87-9ba7-385303bc3068");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f9aac54c-2e7f-4e87-9ba7-385303bc3068' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dadf30ef-0632-4c06-b5c1-e3c74da10058":{"roots":{"references":[{"attributes":{"callback":null},"id":"dee6d71e-efdb-4f76-b8dc-6413278589c8","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1026]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1026]}}},"id":"843fb7df-fbf1-4542-bf3c-fb3d9ffdeb6d","type":"ColumnDataSource"},{"attributes":{"below":[{"id":
","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"6fdbd3f0-8554-4fe1-bbdc-833845747bbf","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"a64ff867-69ee-4bb6-88c5-6dc5afc83015","subtype":"Figure","type":"Plot"},"ticker":{"id":"2f9a55c7-742c-4983-a16e-c0b8f0fb24a2","type":"BasicTicker"}},"id":"9353e16e-3d9f-4dd9-a211-ea2d092e7d1e","type":" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (mV)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
# p.circle(TSweepLowTempH1.ix[:,7],(TSweepLowTempH1.ix[:,1]),color=tableau20[0],legend='Heating #1')
p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
# p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=2.8, dimension='height', line_color='black', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1972b9d5-3db6-4174-b674-3c249c8248f0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1972b9d5-3db6-4174-b674-3c249c8248f0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("ef6b160e-1317-4f53-afb2-a01f602516f0", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1972b9d5-3db6-4174-b674-3c249c8248f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1972b9d5-3db6-4174-b674-3c249c8248f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fdbae438-8262-4bf6-8dbc-7dd1512c165d":{"roots":{"references":[{"attributes":{"callback":null},"id":"131e0318-ed8b-4cef-98fb-3569b4a3273f","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b6e4121f-3dfa-4123-ae96-26764f4f946b","type":"PanTool"},{"id":"becfc110-5fd2-4477-87e7-3f77ac773e66","type":"WheelZoomTool"},{"id":"f9626831-96cb-4f41-9ac3-015978b79426","type":"BoxZoomTool"},{"id":"d3bfb7e7-0679-4bec-906f-cd3d8d355dc4","type":"SaveTool"},{"id":"f3438747-a07b-4090-9b82-b2c360da6c63","type":"ResetTool"},{"id":"fcad4e7f-f840-44ed-b176-07648d2d7976","type":"HelpTool"}]},"id":"e5b54d9d-b18b-4996-aa6b-2d3bea85fde7","type":"Toolbar"},{"attributes":{"plot":null,"text":"Differential strain measurement (10% vs 3 %) 6 May 17"},"id":"18dbf3ec-3037-4e30-991f-10d6bdebc9b1","type":"Title"},{"attributes":{"axis_label":"Temperature (K)","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"2f675e5d-fa52-4c17-842f-3ec19255064a","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"},"ticker":{"id":"f1a43409-6d9a-47d2-a1d7-11b12ca1469b","type":"BasicTicker"}},"id":"cb8e3c2b-8f43-47a0-8826-8ec740bd543e","type":"LinearAxis"},{"attributes":{"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"},"ticker":{"id":"f1a43409-6d9a-47d2-a1d7-11b12ca1469b","type":"BasicTicker"}},"id":"14f2d635-2829-4559-8521-3b2e6d5ae979","type":"Grid"},{"attributes":{"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"}},"id":"f3438747-a07b-4090-9b82-b2c360da6c63","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1bd49b4-9538-42da-948d-d4d3b1b52b2b","type":"BasicTicker"}},"id":"61451981-b239-4977-8cae-311c6dac3e0e","type":"Grid"},{"attributes":{},"id":"f1a43409-6d9a-47d2-a1d7-11b12ca1469b","type":"BasicTicker"},{"attributes":{"callback":null},"id":"8f939f9c-9039-4ecd-b8ff-e64e5c7d0baf","type":"DataRange1d"},{"attributes":{},"id":"c1bd49b4-9538-42da-948d-d4d3b1b52b2b","type":"BasicTicker"},{"attributes":{"axis_label":"Bridge Voltage (mV)","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"87256108-5d1b-4f97-b5fd-41b458499a5f","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1bd49b4-9538-42da-948d-d4d3b1b52b2b","type":"BasicTicker"}},"id":"42492c59-ed57-4004-90b9-ba99b6d20532","type":"LinearAxis"},{"attributes":{"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"}},"id":"b6e4121f-3dfa-4123-ae96-26764f4f946b","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"62168dc8-c009-468b-aa21-751a430fcd59","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"}},"id":"d3bfb7e7-0679-4bec-906f-cd3d8d355dc4","type":"SaveTool"},{"attributes":{"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"}},"id":"becfc110-5fd2-4477-87e7-3f77ac773e66","type":"WheelZoomTool"},{"attributes":{"label":{"value":"Heating #2"},"renderers":[{"id":"7e5c74f4-3bd6-41e2-bedf-ebd5943da8e8","type":"GlyphRenderer"}]},"id":"79577855-3af0-483a-be54-d24746c5ff5c","type":"LegendItem"},{"attributes":{"overlay":{"id":"62168dc8-c009-468b-aa21-751a430fcd59","type":"BoxAnnotation"},"plot":{"id":"dd05f60d-2ed4-4c73-afe2-581db054aa35","subtype":"Figure","type":"Plot"}},"id":"f9626831-96cb-4f41-9ac3 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# Below I present the 3 cycles of cooling and heating in the range of "supposed" first order phase transition and a huge change of lattice constant. On the two cooling cycles a small peak is coming out from the noise. However it is not present in the heating sweeps. Also, the peak height is rather miniscule.

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (mV)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.line(TSweepHighTempH1.ix[:,7],(TSweepHighTempH1.ix[:,1]),line_width=1,line_color=tableau20[2],legend='Heating #1')
p.line(TSweepHighTempC1.ix[:,7],(TSweepHighTempC1.ix[:,1]),line_width=1,line_color=tableau20[0],legend='Cooling #1')
# p.circle(TSweepHighTempC2.ix[:,7],(TSweepHighTempC1.ix[:,1]),size=2,color=tableau20[2],legend='Heating #2')
# p.square(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),size=2,color=tableau20[6],legend='Cooling #2')
# p.square(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]),size=2,color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=14.25, dimension='height', line_color='black',line_dash='dashed', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cfa35adc-e4d7-4c7d-98d0-812e9d6159b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cfa35adc-e4d7-4c7d-98d0-812e9d6159b4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a4263e3e-be4b-4fcb-944c-1d5d31a9efca", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cfa35adc-e4d7-4c7d-98d0-812e9d6159b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cfa35adc-e4d7-4c7d-98d0-812e9d6159b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0de26e32-8bfb-4b9c-a59c-ff2721c2dadb":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ec0f511-9638-416e-b656-474e671ac86a","type":"Line"},{"attributes":{"label":{"value":"Heating #1"},"renderers":[{"id":"84530548-abd3-491e-be63-1f233d883f56","type":"GlyphRenderer"}]},"id":"aef19537-56d3-4c73-9462-8badc23e36aa","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[8798]},"y":{"__ndarray__":"...","dtype":"float64","shape":[8798]}}},"id":"ed4d4db8-1638-434e-9071-0c612203e28c","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ed4d4db8-1638-434e-9071-0c612203e28c","type":"ColumnDataSource"},"glyph":{"id":"022c2ae0-209e-4786-a185-f21603507504","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4ec0f511-9638-416e-b656-474e671ac86a","type":"Line"},"selection_glyph":null},"id":"84530548-abd3-491e-be63-1f233d883f56","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"4630013a-2f05-45b5-b442-92a188d0f691","type":"DataRange1d"},{"attributes":{},"id":"0f8eb307-bfb8-403b-9d27-3e125d7af28b","type":"BasicTickFormatter"},{"attributes":{},"id":"e2879516-a82f-4926-922c-4a28551f4e8c","type":"BasicTickFormatter"},{"attributes":{"items":[{"id":"aef19537-56d3-4c73-9462-8badc23e36aa","type":"LegendItem"},{"id":"61bbf5f5-575c-4dd5-bc73-b02f129c5500","type":"LegendItem"}],"plot":{"id":"2f1b3d67-b9c0-4411-91ae-a26df66020a8","subtype":"Figure","type":"Plot"}},"id":"68a35b6d-2c8a-42f5-b209-af0309be63f9","type":"Legend"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[6334]},"y":{"__ndarray__":"...","dtype":"float64","shape":[6334]}}},"id":"5be59e8e-2a17-4f2c-997f-d900e83d1834","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Differential strain measurement (10% vs 3 %) 6 May 17"},"id":"1ca71694-8dc3-40b3-ab18-03985450f7f2","type":"Title"},{"attributes":{"dimension":"height","line_dash":[6],"location":14.25,"plot":null},"id":"513b64cc-281c-4217-9db4-47e04d0295f1","type":"Span"},{"attributes":{"below":[{"id":"bab89b25-f180-492a-9126-0a79f83a3a6d","type":"LinearAxis"}],"left":[{"id":"81d7fbf1-3564-409a-9c91-178fa96bf183","type":"LinearAxis"}],"renderers":[{"id":"bab89b25-f180-492a-9126-0a79f83a3a6d","type":"LinearAxis"},{"id":"7d313e6e-8832-437e-a997-a25fa314f219","type":"Grid"},{"id":"81d7fbf1-3564-409a-9c91-178fa96bf183","type":"LinearAxis"},{"id":"460ce837-5561-4dfc-832c-982f25dfcff7","type":"Grid"},{"id":"7dd7962d-4b8f-48ae-8e31-b1b8e473dcfc","type":"BoxAnnotation"},{"id":"68a35b6d-2c8a-42f5-b209-af0309be63f9","type":"Legend"},{"id":"84530548-abd3-491e-be63-1f233d883f56","type":"GlyphRenderer"},{"id":"fe76342b-d983-4a2e-a3f3-59e2949e8377","type":"GlyphRenderer"},{"id":"513b64cc-281c-4217-9db4-47e04d0295f1","type":"Span"}],"title":{"id":"1ca71694-8dc3-40b3-ab18-03985450f7f2","type":"Title"},"tool_events":{"id":"98508690-8ca2-44b2-a280-e26f78965ba4","type":"ToolEvents"},"toolbar":{"id":"a556827f-b0b6-4182-956d-9985858be6f3","type":"Toolbar"},"x_range":{"id":"4630013a-2f05-45b5-b442-92a188d0f691","type":"DataRange1d"},"y_range":{"id":"eb9d8bd7-6dc0-44bd-b6cd-758d490def3d","type":"DataRange1d"}},"id":"2f1b3d67-b9c0-4411-91ae-a26df66020a8","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"2f1b3d67-b9c0-4411-91ae-a26df66020a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"64317fb0-5463-446f-8652-f46920a1c4bd","type":"BasicTicker"}},"id":"460ce837-5561-4dfc-832c-982f25dfcff7","type":"Grid"},{"attributes":{},"id":"98508690-8ca2-44b2-a280-e26f78965ba4","type":"ToolEvents"},{"attributes":{"callback":null},"id":"eb9d8bd7-6dc0-44bd-b6cd-758d490def3d","type":"DataRange1d"},{"attributes":{"line_color":{"value":"rgb(31, 119, 180)"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dcc6e4f6-0740-48bf-8805-08843fae4b90","type":"Li ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (mV)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.line(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),line_width=1,line_color=tableau20[4],legend='Heating #2')
p.line(TSweepHighTempC2.ix[:,7],(TSweepHighTempC2.ix[:,1]),line_width=1,line_color=tableau20[6],legend='Cooling #2')
# p.circle(TSweepHighTempC2.ix[:,7],(TSweepHighTempC1.ix[:,1]),size=2,color=tableau20[4],legend='Heating #2')
# p.square(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),size=2,color=tableau20[6],legend='Cooling #2')
# p.square(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]),size=2,color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=14.25, dimension='height', line_color='black',line_dash='dashed', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c6d85aaf-d1b8-47d6-a2e0-9e36a2fd6dc6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c6d85aaf-d1b8-47d6-a2e0-9e36a2fd6dc6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("20c107eb-ae32-4a0d-85f3-0a7080ebd41c", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c6d85aaf-d1b8-47d6-a2e0-9e36a2fd6dc6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c6d85aaf-d1b8-47d6-a2e0-9e36a2fd6dc6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"58bebd5e-d79a-4727-9227-0bce22e5c694":{"roots":{"references":[{"attributes":{"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"},"ticker":{"id":"5b948438-4f95-4591-93f5-938b5a33d322","type":"BasicTicker"}},"id":"6872cc2a-752c-4e2e-9d29-0e09733b13d3","type":"Grid"},{"attributes":{"axis_label":"Bridge Voltage (mV)","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"e6639b23-7ac9-4106-80ce-dd9074a238c5","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"},"ticker":{"id":"655d7f10-36f8-4291-8e93-900c5b478817","type":"BasicTicker"}},"id":"16048826-f0e9-4d57-a44f-b42187f88fa0","type":"LinearAxis"},{"attributes":{},"id":"655d7f10-36f8-4291-8e93-900c5b478817","type":"BasicTicker"},{"attributes":{},"id":"5b948438-4f95-4591-93f5-938b5a33d322","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"},"ticker":{"id":"655d7f10-36f8-4291-8e93-900c5b478817","type":"BasicTicker"}},"id":"dd4c4777-e261-417d-ae89-e48ad4aea056","type":"Grid"},{"attributes":{"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"}},"id":"804f0434-7a59-491b-ae0c-ff8d72c434d2","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c5211c37-23c4-4bf4-b7f0-b5c691a25267","type":"Line"},{"attributes":{"axis_label":"Temperature (K)","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"e0bb24e8-2719-4b3a-84e7-332f1a54b9f1","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"},"ticker":{"id":"5b948438-4f95-4591-93f5-938b5a33d322","type":"BasicTicker"}},"id":"27c9e415-834c-414f-9bb2-a32a0b14f6fe","type":"LinearAxis"},{"attributes":{"line_color":{"value":"rgb(44, 160, 44)"},"x":{"field":"x"},"y":{"field":"y"}},"id":"319c77ee-a733-424d-97b5-7de61bdddd8e","type":"Line"},{"attributes":{"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"}},"id":"3b26989e-dc4c-4b6f-8951-bbcebf67ef16","type":"PanTool"},{"attributes":{"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"}},"id":"1faf0b17-3d09-45c9-a5fb-3564330f1087","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3d9111f4-f4a6-45ca-aa06-e1027f08e77f","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"3d9111f4-f4a6-45ca-aa06-e1027f08e77f","type":"BoxAnnotation"},"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"}},"id":"fc128538-5939-4171-8a01-39b2ba324831","type":"BoxZoomTool"},{"attributes":{"label":{"value":"Heating #2"},"renderers":[{"id":"4ecf6fe7-d8f7-4efb-8752-43e8ca220878","type":"GlyphRenderer"}]},"id":"01ab68f6-e76f-4b4b-adc3-6524c37cb314","type":"LegendItem"},{"attributes":{"plot":{"id":"6c5114a3-0b34-4220-a999-0f9dc71f7a9b","subtype":"Figure","type":"Plot"}},"id":"a5d14404-49e6-4ad7-bd43-9143042903dd","type":"HelpTool"},{"attributes":{"data_source":{"id":"f5c1d09c-6911-4472-aaf8-7fa7de153233","type":"ColumnDataSource"},"glyph":{"id":"319c77ee-a733-424d-97b5-7de61bdddd8e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c5211c37-23c4-4bf4-b7f0-b5c691a25267","type":"Line"},"selection_glyph":null},"id":"4ecf6fe7-d8f7-4efb-8752-43e8ca220878","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"000d9510-f81f-483d-b960-faee74b0af41","type":"Line" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (mV)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.line(TSweepHighTempC2.ix[:,7],(TSweepHighTempC2.ix[:,1]),line_width=1,line_color=tableau20[6],legend='Cooling #2')
p.line(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]),line_width=1,line_color=tableau20[8],legend='Heating #3')
# p.circle(TSweepHighTempC2.ix[:,7],(TSweepHighTempC1.ix[:,1]),size=2,color=tableau20[4],legend='Heating #2')
# p.square(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),size=2,color=tableau20[6],legend='Cooling #2')
# p.square(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]),size=2,color=tableau20[8],legend='Cooling #3')


p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=14.25, dimension='height', line_color='black',line_dash='dashed', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="467b1f28-51e4-46de-aae2-656e54d7e0f9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("467b1f28-51e4-46de-aae2-656e54d7e0f9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("74937b75-2c2a-4818-ada9-1a6cfc07d23f", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("467b1f28-51e4-46de-aae2-656e54d7e0f9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '467b1f28-51e4-46de-aae2-656e54d7e0f9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d4a4e738-5ab2-415f-a797-3c2ac039ad33":{"roots":{"references":[{"attributes":{"label":{"value":"Heating #3"},"renderers":[{"id":"3bb685b9-9a60-4774-b69b-31e53bd07c49","type":"GlyphRenderer"}]},"id":"f2eee9aa-0987-4605-98b1-bd2a07f79b45","type":"LegendItem"},{"attributes":{"dimension":"height","line_dash":[6],"location":14.25,"plot":null},"id":"713ecc6d-074f-4e1c-9467-b2535b8d1f28","type":"Span"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[4250]},"y":{"__ndarray__":"...","dtype":"float64","shape":[4250]}}},"id":"eee9c0cf-a233-402a-8245-2fc2a66e9b2d","type":"ColumnDataSource"},{"attributes":{},"id":"3ee6c340-089f-4baf-a333-9c16a7eb230d","type":"BasicTickFormatter"},{"attributes":{"items":[{"id":
","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"3ee6c340-089f-4baf-a333-9c16a7eb230d","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"0bdc6be5-9da2-4050-98ec-92865f1ec19f","subtype":"Figure","type":"Plot"},"ticker":{" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %% [markdown]
# The magnetic field measurements are inconsistent. At 5 K we see a clear maximum in the measured bridge voltage, however we would expect a minimum as the sample with 3 % Mn should not exhibit any magnetostriction in this temperature. Interestingly, there is no indiciation of any magnetostriction in 12 K in low fields. In the temperatures 5 and 6 we see a shallow extrema of the bridge resistance and it is hard to guess whether they are attributed to a measurement noise or the real response of the sample (if any).

# %%
p = figure(title="6 May 17", x_axis_label='Field (Oe)', y_axis_label='Bridge Voltage (mV)')
p.x_range=Range1d(-400,400)
# p.y_range=Range1d(1.003,1.005)
p.circle(HSweep8K.ix[:,8],(HSweep8K.ix[:,1]),size=1,color=tableau20[0],legend='T= 8 K')
p.circle(HSweep6K.ix[:,8],(HSweep6K.ix[:,1]),size=1,color=tableau20[2],legend='T= 6 K')
p.circle(HSweep5K.ix[:,8],(HSweep5K.ix[:,1]),size=1,color=tableau20[4],legend='T= 5 K')
p.circle(HSweep12K.ix[:,8],(HSweep12K.ix[:,1]),size=1,color=tableau20[6],legend='T= 12 K')



# p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
# p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
# p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')


p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"




p.title.text_font_size='16pt'
p.title.text_font = "helvetica"

vline = Span(location=2.8, dimension='height', line_color='black', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="619f503c-d8a3-4ee3-b85b-c6cdb230a864"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("619f503c-d8a3-4ee3-b85b-c6cdb230a864").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("c3ebf7ec-24e6-4b02-9ca2-b9dcaf389e12", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("619f503c-d8a3-4ee3-b85b-c6cdb230a864");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '619f503c-d8a3-4ee3-b85b-c6cdb230a864' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d73e9f1d-0abf-4a17-bfca-ee634e3eb992":{"roots":{"references":[{"attributes":{"plot":{"id":"5034af2f-934c-4a4e-8e3c-2912fb1a087f","subtype":"Figure","type":"Plot"}},"id":"46284bed-b292-4a04-8046-f3b0b10e7f89","type":"PanTool"},{"attributes":{"callback":null},"id":"bf2f3ce5-d5c7-4e94-a47f-7c868872fa64","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"40d3ebc0-0321-46c8-a50e-33b34a8c67b5","type":"BoxAnnotation"},{"attributes":{"axis_label":"Field (Oe)","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"967628cf-491d-43d2-bab1-5210f302666f","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"plot":{"id":"5034af2f-934c-4a4e-8e3c-2912fb1a087f","subtype":"Figure","type":"Plot"},"ticker":{"id":"8