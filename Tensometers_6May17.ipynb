# %%
import matplotlib as mpl
mpl.use("nbagg")
import matplotlib.pyplot as plt
from ipywidgets import *
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib notebook 
# init_notebook_mode()
from IPython.display import HTML
V=4e-1*1.041e-1*0.74e-1
V100=1.038*1e-1*3.9405*1e-1*0.76e-1
m=0.0239
m2=0.0255
m3=0.00585
from IPython.display import Image

HTML('''
<style>

div.cell { /* Tunes the space between cells */
margin-top:1em;
margin-bottom:1em;
}

div.text_cell_render h1 { /* Main titles bigger, centered */
font-size: 1.5em;
line-height:1.5em;
text-align:left;
}

div.text_cell_render h2 { /*  Parts names nearer from text */
margin-bottom: -0.4em;
}


div.text_cell_render { /* Customize text cells */
font-family: 'Helvetica';
font-size:1.2em;
line-height:2em;
padding-left:3em;
padding-right:3em;
}
</style>

<script>
code_show=true; 
function code_toggle() {
if (code_show){
$('div.input').hide();
} else {
$('div.input').show();
}
code_show = !code_show
} 
$( document ).ready(code_toggle);

</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <style>
#
# div.cell { /* Tunes the space between cells */
# margin-top:1em;
# margin-bottom:1em;
# }
#
# div.text_cell_render h1 { /* Main titles bigger, centered */
# font-size: 1.5em;
# line-height:1.5em;
# text-align:left;
# }
#
# div.text_cell_render h2 { /*  Parts names nearer from text */
# margin-bottom: -0.4em;
# }
#
#
# div.text_cell_render { /* Customize text cells */
# font-family: 'Helvetica';
# font-size:1.2em;
# line-height:2em;
# padding-left:3em;
# padding-right:3em;
# }
# </style>
#
# <script>
# code_show=true;
# function code_toggle() {
# if (code_show){
# $('div.input').hide();
# } else {
# $('div.input').show();
# }
# code_show = !code_show
# }
# $( document ).ready(code_toggle);
#
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
#################################
#Beauitiful plot maker in Python#
#################################
#

# These are the "Tableau 20" colors as RGB.    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)      
## TeX preamble
# preamble = [
#     r'\usepackage{fontspec}',
#     r'\setmainfont{Minion Pro}',
#     r'\usepackage[textlf,mathlf,minionint]{MinionPro}'
# ]

params = {
    'font.family': 'sans-serif',
    'font.sans-serif':['Calibri'],
    'text.usetex': False,
    'text.latex.unicode': False,
    'pgf.rcfonts': False,
    'pgf.texsystem': 'xelatex',
}

mpl.rcParams.update(params)

# %%
from IPython.display import HTML
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.models import * 
from bokeh.plotting import figure
from bokeh.charts.utils import cycle_colors
from bokeh.palettes import *
from bokeh.palettes import viridis as palette
import itertools
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f851d7b3-0a9b-4bd3-8a49-1600fec4f8a2">Loading BokehJS ...</span>
#     </div>

# %%
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

# %%
dir='../StudiaDoktoranckie/2017/Tensometry/'
TSweepLowTempC1=pd.read_csv(dir+'Tensometr5May17_T4-2K_Cooling#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempC2=pd.read_csv(dir+'Tensometr5May17_T4-2K_Cooling#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempC3=pd.read_csv(dir+'Tensometr5May17_T4-2K_Cooling#3.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempH1=pd.read_csv(dir+'Tensometr5May17_T4-2K_Heating#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepLowTempH2=pd.read_csv(dir+'Tensometr5May17_T4-2K_Heating#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempC1=pd.read_csv(dir+'Tensometr5May17_T10-17K_Cooling#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempC2=pd.read_csv(dir+'Tensometr5May17_T10-17K_Cooling#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempH1=pd.read_csv(dir+'Tensometr5May17_T10-17K_Heating#1.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempH2=pd.read_csv(dir+'Tensometr5May17_T10-17K_Heating#2.csv',sep=',',header=0,error_bad_lines=False)
TSweepHighTempH3=pd.read_csv(dir+'Tensometr5May17_T10-17K_Heating#3.csv',sep=',',header=0,error_bad_lines=False)
HSweep8K=pd.read_csv(dir+'Tensometr6May17_H_8K#2.csv',sep=',',header=0,error_bad_lines=False)
HSweep6K=pd.read_csv(dir+'Tensometr6May17_H_6K.csv',sep=',',header=0,error_bad_lines=False)
HSweep5K=pd.read_csv(dir+'Tensometr6May17_H_5K.csv',sep=',',header=0,error_bad_lines=False)
HSweep12K=pd.read_csv(dir+'Tensometr6May17_H_12K.csv',sep=',',header=0,error_bad_lines=False)
RawTempSweep=pd.read_csv(dir+'Tensometr4May17TwoSamples.csv',sep=',',header=0,error_bad_lines=False)
SlowTempSweep=pd.read_csv(dir+'Tensometr6May17_T10_17_Slow.csv',sep=',',header=0,error_bad_lines=False)

# %% [markdown]
# # 4 - 5 May Overnight absolute measurement of a tensometers alone.

# %% [markdown]
# The tensometers where fed with the 100 $\mu$A RMS current. Temperature was swept in the rate 2 K/min. The measurement was carried out in the 7 T Squid which was previously de-gaussed with "5 T fast" procedure. Systems cryogenic performance was malfunctioning during the measurement.
#
# We have veryfied, that resistance characteristic ilustrated below can be attributed to strain gage. We have not seen any signature of sample behavior in this measurement.
#
# On the picture below, the <font color="red"> red</font> line is indicating $T_{\rm C}$ of 10 % sample, the <font color="blue"> blue </font> one of the 3 %.
#
# The kink at ~120 K is due to Squid cooling problems.

# %%
p = figure(title="Absolute strain measurement (10% vs 3 %) 4 May 17", x_axis_label='Temperature (K)', y_axis_label='Tensometer Resistance (Ohms)')
p.x_range=Range1d(-1,299)
# p.y_range=Range1d(1.003,1.005)
p.circle(RawTempSweep.ix[:,7],(RawTempSweep.ix[:,1])/1e-4,size=1,color=tableau20[0],legend='10 %')
p.circle(RawTempSweep.ix[:,7],(RawTempSweep.ix[:,2]+0.03568)/1e-4,size=1,color=tableau20[2],legend='3 %')
# p.circle(HSweep5K.ix[:,8],(HSweep5K.ix[:,1]),size=1,color=tableau20[4],legend='T= 5 K')
# p.circle(HSweep12K.ix[:,8],(HSweep12K.ix[:,1]),size=1,color=tableau20[6],legend='T= 12 K')



# p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
# p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
# p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')


p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

p.title.text_font_size='16pt'
p.title.text_font = "helvetica"

vline1 = Span(location=2.8, dimension='height', line_color='blue', line_width=1)
vline2 = Span(location=14.2, dimension='height', line_color='red', line_width=1)

p.renderers.extend([vline1,vline2])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e45d49ee-e63d-4f50-85c9-39e867be0e1c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# # Differential measurements 5 and 6 May 17

# %% [markdown]
# As it is shown on the picture above, strain gages are exhibiting steep increase of resistance in the low temperatures. Due to resistance rapid increase, a possibility of detection of the phase transition in low-temp regime is questionable. Low temperature differential measurements presented below are indicating siginificant slope between 4-2 K. I think, we won't be able to detect phase transition of 3 % sample in this region.

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (V)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.circle(TSweepLowTempH1.ix[:,7],(TSweepLowTempH1.ix[:,1]),color=tableau20[0],legend='Heating #1')
# p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
# p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=2.8, dimension='height', line_color='blue', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a47248ac-c8e5-4d4c-a51d-eb8e505d9682"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (V)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
# p.circle(TSweepLowTempH1.ix[:,7],(TSweepLowTempH1.ix[:,1]),color=tableau20[0],legend='Heating #1')
p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
# p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=2.8, dimension='height', line_color='blue', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="52609740-1f04-4621-b8cf-c8dba207c2be"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# Below I present the 3 cycles of cooling and heating in the range of "supposed" first order phase transition and a huge change of lattice constant. On the two cooling cycles a small peak is coming out from the noise. However it is not present in the heating sweeps. Also, the peak height is rather miniscule. Sweeps were carried out with 0.1 K/min rate. <b>Also there is artificial offset between the curves for clarity of illustration</b>.

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (V)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.line(TSweepHighTempH1.ix[:,7],(TSweepHighTempH1.ix[:,1]),line_width=1,line_color=tableau20[2],legend='Heating #1')
p.line(TSweepHighTempC1.ix[:,7],(TSweepHighTempC1.ix[:,1]+1e-6),line_width=1,line_color=tableau20[0],legend='Cooling #1')
# p.circle(TSweepHighTempC2.ix[:,7],(TSweepHighTempC1.ix[:,1]),size=2,color=tableau20[2],legend='Heating #2')
# p.square(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),size=2,color=tableau20[6],legend='Cooling #2')
# p.square(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]),size=2,color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=14.25, dimension='height', line_color='red',line_dash='dashed', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d6d971c6-e422-4409-8764-54d2fa3e5a09"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (V)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.line(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),line_width=1,line_color=tableau20[4],legend='Heating #2')
p.line(TSweepHighTempC2.ix[:,7],(TSweepHighTempC2.ix[:,1]+1e-6),line_width=1,line_color=tableau20[6],legend='Cooling #2')
# p.circle(TSweepHighTempC2.ix[:,7],(TSweepHighTempC1.ix[:,1]),size=2,color=tableau20[4],legend='Heating #2')
# p.square(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),size=2,color=tableau20[6],legend='Cooling #2')
# p.square(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]),size=2,color=tableau20[8],legend='Cooling #3')



p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=14.25, dimension='height', line_color='red',line_dash='dashed', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c049b0e2-ae29-4734-aa4e-5a729f28b162"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
p = figure(title="Differential strain measurement (10% vs 3 %) 6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (V)')
# p.x_range=Range1d(2, 4.2)
# p.y_range=Range1d(1.003,1.005)
p.line(TSweepHighTempC2.ix[:,7],(TSweepHighTempC2.ix[:,1]),line_width=1,line_color=tableau20[6],legend='Cooling #2')
p.line(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]+1e-6),line_width=1,line_color=tableau20[8],legend='Heating #3')
# p.circle(TSweepHighTempC2.ix[:,7],(TSweepHighTempC1.ix[:,1]),size=2,color=tableau20[4],legend='Heating #2')
# p.square(TSweepHighTempH2.ix[:,7],(TSweepHighTempH2.ix[:,1]),size=2,color=tableau20[6],legend='Cooling #2')
# p.square(TSweepHighTempH3.ix[:,7],(TSweepHighTempH3.ix[:,1]),size=2,color=tableau20[8],legend='Cooling #3')


p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"

vline = Span(location=14.25, dimension='height', line_color='red',line_dash='dashed', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f0ca9640-da72-466b-bdef-f82730bbadf8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# As there is no conclusive behavior of strain gages coming from the above measurements. I performed very slow (0.05 K/min) temperature sweep to see if there is any signature of phase transition. Unfortunately there is no signature that can be unambigously attributed to phase transition.

# %%
p = figure(title="6 May 17", x_axis_label='Temperature (K)', y_axis_label='Bridge Voltage (V)')
# p.x_range=Range1d(-400,400)
# p.y_range=Range1d(1.003,1.005)
p.circle(SlowTempSweep.ix[:,7],(SlowTempSweep.ix[:,1]),size=1,color=tableau20[0],legend='0.05 K/min')



# p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
# p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
# p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')


p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"




p.title.text_font_size='16pt'
p.title.text_font = "helvetica"

vline = Span(location=14.2, dimension='height', line_color='red', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3f29a201-29ae-49ac-aa5d-e958563dda47"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# # Strain vs Magnetic Field

# %% [markdown]
# The magnetic field measurements are inconsistent. At 5 K we see a clear maximum in the measured bridge voltage, however we would expect a minimum as the sample with 3 % Mn should not exhibit any magnetostriction in this temperature. Interestingly, there is no indiciation of any magnetostriction in 12 K in low fields. In the temperatures 5 and 6 we see a shallow extrema of the bridge resistance and it is hard to guess whether they are attributed to a measurement noise or the real response of the sample (if any).

# %%
p = figure(title="6 May 17", x_axis_label='Field (Oe)', y_axis_label='Bridge Voltage (V)')
p.x_range=Range1d(-400,400)
# p.y_range=Range1d(1.003,1.005)
p.circle(HSweep8K.ix[:,8],(HSweep8K.ix[:,1]),size=1,color=tableau20[0],legend='T= 8 K')
p.circle(HSweep6K.ix[:,8],(HSweep6K.ix[:,1]),size=1,color=tableau20[2],legend='T= 6 K')
p.circle(HSweep5K.ix[:,8],(HSweep5K.ix[:,1]),size=1,color=tableau20[4],legend='T= 5 K')
p.circle(HSweep12K.ix[:,8],(HSweep12K.ix[:,1]),size=1,color=tableau20[6],legend='T= 12 K')



# p.circle(TSweepLowTempH2.ix[:,7],(TSweepLowTempH2.ix[:,1]),color=tableau20[2],legend='Heating #2')
# p.square(TSweepLowTempC1.ix[:,7],(TSweepLowTempC1.ix[:,1]),color=tableau20[4],legend='Cooling #1')
# p.square(TSweepLowTempC2.ix[:,7],(TSweepLowTempC2.ix[:,1]),color=tableau20[6],legend='Cooling #2')
# p.square(TSweepLowTempC3.ix[:,7],(TSweepLowTempC3.ix[:,1]),color=tableau20[8],legend='Cooling #3')


p.xaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font_size = "14pt"
p.yaxis.axis_label_text_font = "helvetica"
p.xaxis.axis_label_text_font = "helvetica"
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size = "12pt"
p.yaxis.major_label_text_font = "helvetica"
p.xaxis.major_label_text_font = "helvetica"




p.title.text_font_size='16pt'
p.title.text_font = "helvetica"

vline = Span(location=2.8, dimension='height', line_color='black', line_width=1)
p.renderers.extend([vline])
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c1cc13c2-4585-4af7-8587-56cc4b335e37"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
